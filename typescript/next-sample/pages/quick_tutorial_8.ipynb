# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/souta-pqr/.local/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: numpy<2,>=1.21 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=8 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/souta-pqr/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install torch
# !pip install torchvision
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/souta-pqr/.local/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: filelock in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: fsspec in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: triton==2.2.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: sympy in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (3.1.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/souta-pqr/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from jinja2->torch) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /home/souta-pqr/.local/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchvision in /home/souta-pqr/.local/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: torch==2.2.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torchvision) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: requests in /home/souta-pqr/.local/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: numpy in /home/souta-pqr/.local/lib/python3.10/site-packages (from torchvision) (1.26.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (12.1.0.106)
# Requirement already satisfied: networkx in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (3.2.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (12.1.105)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (4.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (2.2.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (11.4.5.107)
# Requirement already satisfied: filelock in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (3.13.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (2.19.3)
# Requirement already satisfied: fsspec in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (2023.12.2)
# Requirement already satisfied: sympy in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (1.12)
# Requirement already satisfied: jinja2 in /home/souta-pqr/.local/lib/python3.10/site-packages (from torch==2.2.0->torchvision) (3.1.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/souta-pqr/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.0->torchvision) (12.3.101)
# Requirement already satisfied: idna<4,>=2.5 in /home/souta-pqr/.local/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/souta-pqr/.local/lib/python3.10/site-packages (from requests->torchvision) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/souta-pqr/.local/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/souta-pqr/.local/lib/python3.10/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/souta-pqr/.local/lib/python3.10/site-packages (from jinja2->torch==2.2.0->torchvision) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /home/souta-pqr/.local/lib/python3.10/site-packages (from sympy->torch==2.2.0->torchvision) (1.3.0)

# %%
# 訓練データをdatasetsからダウンロード
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# テストデータをdatasetsからダウンロード
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
batch_size = 64

# データローダの作成
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([64, 1, 28, 28])
# Shape of y:  torch.Size([64]) torch.int64

# %%
# 訓練に際して，可能であればGPU(cuda)を設定します．GPUが搭載されていない場合はCPUを使用します．
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

# モデルの定義
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512), # 28*28=784
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10), # 10はクラス数
            nn.ReLU()
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#     (5): ReLU()
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device) # GPUを使用する場合は，データをGPUに転送します．

        # 損失誤差を計算
        pred = model(X)
        loss = loss_fn(pred, y)

        # バックプロパゲーション
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch*len(X)
            print(f"loss: {loss:>7f} [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model):
    size = len(dataloader.dataset)
    model.eval() # モデルを評価モードに設定 
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1)==y).type(torch.float).sum().item()
    test_loss /= size
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.497800 [    0/60000]
# loss: 1.519281 [ 6400/60000]
# loss: 1.282117 [12800/60000]
# loss: 1.463509 [19200/60000]
# loss: 1.400621 [25600/60000]
# loss: 1.475545 [32000/60000]
# loss: 1.470335 [38400/60000]
# loss: 1.373417 [44800/60000]
# loss: 1.575682 [51200/60000]
# loss: 1.648710 [57600/60000]
# Test Error:
#  Accuracy: 55.0%, Avg loss: 0.022539
#
# Epoch 2
# -------------------------------
# loss: 1.439084 [    0/60000]
# loss: 1.467010 [ 6400/60000]
# loss: 1.244010 [12800/60000]
# loss: 1.437488 [19200/60000]
# loss: 1.353842 [25600/60000]
# loss: 1.446131 [32000/60000]
# loss: 1.429904 [38400/60000]
# loss: 1.341710 [44800/60000]
# loss: 1.535153 [51200/60000]
# loss: 1.615013 [57600/60000]
# Test Error:
#  Accuracy: 55.5%, Avg loss: 0.022013
#
# Epoch 3
# -------------------------------
# loss: 1.394619 [    0/60000]
# loss: 1.425918 [ 6400/60000]
# loss: 1.214410 [12800/60000]
# loss: 1.419011 [19200/60000]
# loss: 1.321972 [25600/60000]
# loss: 1.422214 [32000/60000]
# loss: 1.401146 [38400/60000]
# loss: 1.321525 [44800/60000]
# loss: 1.505027 [51200/60000]
# loss: 1.586945 [57600/60000]
# Test Error:
#  Accuracy: 55.7%, Avg loss: 0.021589
#
# Epoch 4
# -------------------------------
# loss: 1.360122 [    0/60000]
# loss: 1.392829 [ 6400/60000]
# loss: 1.190339 [12800/60000]
# loss: 1.403181 [19200/60000]
# loss: 1.299827 [25600/60000]
# loss: 1.399413 [32000/60000]
# loss: 1.379036 [38400/60000]
# loss: 1.307211 [44800/60000]
# loss: 1.479978 [51200/60000]
# loss: 1.560892 [57600/60000]
# Test Error:
#  Accuracy: 56.0%, Avg loss: 0.021213
#
# Epoch 5
# -------------------------------
# loss: 1.330813 [    0/60000]
# loss: 1.364215 [ 6400/60000]
# loss: 1.169680 [12800/60000]
# loss: 1.390264 [19200/60000]
# loss: 1.282272 [25600/60000]
# loss: 1.377197 [32000/60000]
# loss: 1.360751 [38400/60000]
# loss: 1.296228 [44800/60000]
# loss: 1.458756 [51200/60000]
# loss: 1.537989 [57600/60000]
# Test Error:
#  Accuracy: 56.3%, Avg loss: 0.020881
#
# Epoch 6
# -------------------------------
# loss: 1.305447 [    0/60000]
# loss: 1.339077 [ 6400/60000]
# loss: 1.151227 [12800/60000]
# loss: 1.379736 [19200/60000]
# loss: 1.268191 [25600/60000]
# loss: 1.356682 [32000/60000]
# loss: 1.346121 [38400/60000]
# loss: 1.287378 [44800/60000]
# loss: 1.441336 [51200/60000]
# loss: 1.518838 [57600/60000]
# Test Error:
#  Accuracy: 56.5%, Avg loss: 0.020593
#
# Epoch 7
# -------------------------------
# loss: 1.283733 [    0/60000]
# loss: 1.317613 [ 6400/60000]
# loss: 1.134882 [12800/60000]
# loss: 1.371050 [19200/60000]
# loss: 1.256505 [25600/60000]
# loss: 1.338292 [32000/60000]
# loss: 1.334187 [38400/60000]
# loss: 1.280210 [44800/60000]
# loss: 1.427186 [51200/60000]
# loss: 1.502214 [57600/60000]
# Test Error:
#  Accuracy: 56.8%, Avg loss: 0.020343
#
# Epoch 8
# -------------------------------
# loss: 1.265413 [    0/60000]
# loss: 1.299269 [ 6400/60000]
# loss: 1.119946 [12800/60000]
# loss: 1.363748 [19200/60000]
# loss: 1.246763 [25600/60000]
# loss: 1.321929 [32000/60000]
# loss: 1.324609 [38400/60000]
# loss: 1.275029 [44800/60000]
# loss: 1.415741 [51200/60000]
# loss: 1.487305 [57600/60000]
# Test Error:
#  Accuracy: 57.0%, Avg loss: 0.020127
#
# Epoch 9
# -------------------------------
# loss: 1.249415 [    0/60000]
# loss: 1.283696 [ 6400/60000]
# loss: 1.106261 [12800/60000]
# loss: 1.357419 [19200/60000]
# loss: 1.238531 [25600/60000]
# loss: 1.306826 [32000/60000]
# loss: 1.316450 [38400/60000]
# loss: 1.270896 [44800/60000]
# loss: 1.406393 [51200/60000]
# loss: 1.473986 [57600/60000]
# Test Error:
#  Accuracy: 57.0%, Avg loss: 0.019936
#
# Epoch 10
# -------------------------------
# loss: 1.235581 [    0/60000]
# loss: 1.270219 [ 6400/60000]
# loss: 1.093525 [12800/60000]
# loss: 1.351997 [19200/60000]
# loss: 1.231068 [25600/60000]
# loss: 1.292971 [32000/60000]
# loss: 1.309604 [38400/60000]
# loss: 1.267455 [44800/60000]
# loss: 1.398884 [51200/60000]
# loss: 1.462227 [57600/60000]
# Test Error:
#  Accuracy: 57.3%, Avg loss: 0.019766
#
# Done!

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle Boot",
]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "Ankle Boot", Actual: "Ankle Boot"
